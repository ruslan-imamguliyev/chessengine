# %%
import warnings
warnings.filterwarnings("ignore")
from pathlib import Path
import os
os.chdir(str(Path(os.getcwd()).parent))
import mlflow
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['MLFLOW_TRACKING_PASSWORD'] = os.getenv("MLFLOW_TRACKING_PASSWORD")
os.environ['MLFLOW_TRACKING_USERNAME'] = os.getenv("MLFLOW_TRACKING_USERNAME")
os.environ['MLFLOW_TRACKING_URI'] = os.getenv("MLFLOW_TRACKING_URI")

# %%
from src.config.manager import ConfigurationManager
from src.models import ModelManager
config = ConfigurationManager()
model_manager = ModelManager(config)

# %%
model_name = model_manager.get_model_name()

# %%
with mlflow.start_run(run_name=model_name):
  mlflow.log_param('parameter name', 'value')
  mlflow.log_metric('metric name', 1)
  mlflow.log_metric('metric name', 2, step=1)
# Out:
# 🏃 View run resnet_24M_se at: https://dagshub.com/ruslan-imamguliyev/chessengine.mlflow/#/experiments/0/runs/5a7ef78cf4de4f68b1d4cfabb0126c8b
# 🧪 View experiment at: https://dagshub.com/ruslan-imamguliyev/chessengine.mlflow/#/experiments/0
