# %%
import os
os.chdir("../")

# %%
from src.data.entity import DatasetEntity
from src.config.manager import ConfigurationManager
config = ConfigurationManager()

# %%
from src.utils import plot_planes, tensor_to_fen

# %%
dataset_entity = DatasetEntity(config)
# Out:
# [02/22/2026 17:54:42] [INFO] [entity] - Creating train dataset with 950000 samples.
# [02/22/2026 17:54:42] [INFO] [entity] - Creating val dataset with 50000 samples.

# %%
train_set = dataset_entity.get_data_set("train")
train_set

# %%
for position, evaluations in train_loader:
    print("target mean:", evaluations.mean().item())
    print("target std:", evaluations.std().item())
    print("target min:", evaluations.min().item())
    print("target max:", evaluations.max().item())
# Out:
# target mean: 0.06379944086074829
# target std: 0.3428114652633667
# target min: -0.9404581785202026
# target max: 0.8849185705184937
